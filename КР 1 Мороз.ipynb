# %% [markdown]
# ### Data Preprocessing

# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %% [markdown]
# ### Importing data

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
df = pd.read_excel('КР-1.xlsx', sheet_name='Вар (12)')

# %%
df
# Out:
#     Площадь загальна кв.м  Этаж  Количество сотрудников в магазине      Тип  \
# 0                    9.00     1                                   1  старий
# 1                   30.00     1                                   1  старий
# 2                   15.00     1                                   1  старий
# 3                   20.00     1                                   1  старий
# 4                   30.00     1                                   1   новий
# ..                    ...   ...                                 ...     ...
# 64                  51.77     1                                   3   новий
# 65                  27.26     1                                   2   новий
# 66                 148.91     1                                   1  старий
# 67                  50.93     1                                   2   новий
# 68                  30.00     1                                   2   новий
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Площадь загальна кв.м               69 non-null     float64
#  1   Этаж                                69 non-null     int64
#  2   Количество сотрудников в магазине   69 non-null     int64
#  3   Тип                                 69 non-null     object
#  4   Рейтинг в гуглі                     69 non-null     float64
#  5   Количество чеков в месяц            69 non-null     float64
#  6   Средний чек                         62 non-null     float64
#  7   Середній дохід населення            64 non-null     float64
#  8   Населення середнє                   64 non-null     float64
#  9   Спеціалізований хліб                69 non-null     int64
#  10  Спеціалізоване м'ясо                69 non-null     int64
# ...

# %%
# Drop useless
df = df.drop(['Этаж'], axis='columns', inplace=False)

# %% [markdown]
# ### Statistics

# %%
df.describe()
# Out:
#        Площадь загальна кв.м  Количество сотрудников в магазине   \
# count              69.000000                           69.000000
# mean               47.412725                            1.869565
# std                37.862989                            0.838645
# min                 4.000000                            1.000000
# 25%                26.720000                            1.000000
# 50%                32.300000                            2.000000
# 75%                56.240000                            2.000000
# max               232.300000                            4.000000
#
#        Рейтинг в гуглі  Количество чеков в месяц  Средний чек  \
# count        69.000000                 69.000000    62.000000
# mean          3.810145               7105.030583    95.897581
# std           0.695605               4052.584218    19.192685
# min           1.800000                878.000000    65.270000
# 25%           3.000000               3734.000000    82.420000
# ...

# %% [markdown]
# ### Missing data

# %%
df.dtypes
# Out:
# Площадь загальна кв.м                 float64
# Количество сотрудников в магазине       int64
# Тип                                    object
# Рейтинг в гуглі                       float64
# Количество чеков в месяц              float64
# Средний чек                           float64
# Середній дохід населення              float64
# Населення середнє                     float64
# Спеціалізований хліб                    int64
# Спеціалізоване м'ясо                    int64
# Спеціалізований сир                     int64
# Спеціалізована поб. Хімія               int64
# Супермаркет                             int64
# dtype: object

# %%
# Cheking Missing data
df.isnull().sum()
# Out:
# Площадь загальна кв.м                 0
# Количество сотрудников в магазине     0
# Тип                                   0
# Рейтинг в гуглі                       0
# Количество чеков в месяц              0
# Средний чек                           7
# Середній дохід населення              5
# Населення середнє                     5
# Спеціалізований хліб                  0
# Спеціалізоване м'ясо                  0
# Спеціалізований сир                   0
# Спеціалізована поб. Хімія             0
# Супермаркет                           0
# dtype: int64

# %%
#!pip install sklearn

# %%
from sklearn.impute import SimpleImputer

imputer_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
df[['Средний чек']] = imputer_mean.fit_transform(df[['Средний чек']]).round()
df[['Середній дохід населення']] = imputer_mean.fit_transform(df[['Середній дохід населення']]).round()
df[['Населення середнє']] = imputer_mean.fit_transform(df[['Населення середнє']]).round()

# %%
df.isnull().sum()
# Out:
# Площадь загальна кв.м                 0
# Количество сотрудников в магазине     0
# Тип                                   0
# Рейтинг в гуглі                       0
# Количество чеков в месяц              0
# Средний чек                           0
# Середній дохід населення              0
# Населення середнє                     0
# Спеціалізований хліб                  0
# Спеціалізоване м'ясо                  0
# Спеціалізований сир                   0
# Спеціалізована поб. Хімія             0
# Супермаркет                           0
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
df.describe()
# Out:
#        Площадь загальна кв.м  Количество сотрудников в магазине   \
# count              69.000000                           69.000000
# mean               47.412725                            1.869565
# std                37.862989                            0.838645
# min                 4.000000                            1.000000
# 25%                26.720000                            1.000000
# 50%                32.300000                            2.000000
# 75%                56.240000                            2.000000
# max               232.300000                            4.000000
#
#        Рейтинг в гуглі  Количество чеков в месяц  Средний чек  \
# count        69.000000                 69.000000    69.000000
# mean          3.810145               7105.030583    95.942029
# std           0.695605               4052.584218    18.185227
# min           1.800000                878.000000    65.000000
# 25%           3.000000               3734.000000    85.000000
# ...

# %%
# Function Outliers
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
# Outliers
df = outliers(df)
df.describe()
# Out:
#        Площадь загальна кв.м  Количество сотрудников в магазине   \
# count              69.000000                           69.000000
# mean               46.379416                            1.869565
# std                33.459958                            0.838645
# min                 4.000000                            1.000000
# 25%                26.720000                            1.000000
# 50%                32.300000                            2.000000
# 75%                56.240000                            2.000000
# max               161.001691                            4.000000
#
#        Рейтинг в гуглі  Количество чеков в месяц  Средний чек  \
# count        69.000000                 69.000000    69.000000
# mean          3.810145               7105.030583    95.688373
# std           0.695605               4052.584218    17.264082
# min           1.800000                878.000000    65.000000
# 25%           3.000000               3734.000000    85.000000
# ...

# %% [markdown]
# ### Encoding

# %%
# Cheking categorical data
dfs = df[['Тип']]
info = []
for column in dfs.columns:
        vals = {"col": column,
                "nunique": dfs[column].nunique(),
                "unique": dfs[column].unique(),
                "type": dfs[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#    col  nunique                   unique    type
# 0  Тип        3  [старий, новий, cтарий]  object

# %%
# Encoding
type = {'новий':0,'старий':1,'cтарий':1}
df['Тип'] = df['Тип'].map(type)
df
# Out:
#     Площадь загальна кв.м  Количество сотрудников в магазине   Тип  \
# 0                    9.00                                   1    1
# 1                   30.00                                   1    1
# 2                   15.00                                   1    1
# 3                   20.00                                   1    1
# 4                   30.00                                   1    0
# ..                    ...                                 ...  ...
# 64                  51.77                                   3    0
# 65                  27.26                                   2    0
# 66                 148.91                                   1    1
# 67                  50.93                                   2    0
# 68                  30.00                                   2    0
#
#     Рейтинг в гуглі  Количество чеков в месяц  Средний чек  \
# 0               3.0                    1230.0    77.000000
# ...

# %% [markdown]
# ### Correlations

# %%
# Cheking correlations
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# ### Splitting

# %%
# Splitting the dataset into the Training set and Test set

f = ['Площадь загальна кв.м','Тип','Рейтинг в гуглі','Средний чек','Середній дохід населення','Населення середнє','Спеціалізований хліб','Спеціалізований сир','Спеціалізована поб. Хімія','Супермаркет']
X = df[f]
y = df['Количество чеков в месяц']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ### Simple Linear Regression

# %%
# Fitting Simple Linear Regression to the Training set (M2)
f1 = ['Средний чек']

from sklearn.linear_model import LinearRegression
sr = LinearRegression().fit(X_train[f1], y_train)

# Getting parameters
sr.coef_, sr.intercept_
# Out:
# (array([135.61605825]), -5710.312907492007)

# %%
# Predicting the Test set results
y_pred = sr.predict(X_test[f1])

# Coefficient of determination R^2
sr.score(X_train[f1], y_train).round(3)
# Out:
# 0.312

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, sr.predict(X_train[f1]), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (3415.64, 3821.97)

# %%
# Visualising the Test set results
plt.scatter(X_test['Средний чек'], y_test, color = 'red')
plt.plot(X_test['Средний чек'], sr.predict(X_test[f1]), 'bo')
plt.title('Количество чеков в месяц vs Средний чек (Test set)')
plt.xlabel('Средний чек')
plt.ylabel('Количество чеков в месяц')
plt.show()

# %% [markdown]
# ### Multiple Linear Regression

# %%
#!pip install statsmodels

# %%
# Fitting Multiple Regression
mr = LinearRegression().fit(X_train, y_train)

# Coefficient of determination R^2
mr.score(X_train, y_train).round(3)
# Out:
# 0.555

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, mr.predict(X_train), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (2747.19, 3821.97)

# %%
# Visualising the Test set results
plt.scatter(X_test['Средний чек'], y_test, color = 'red')
plt.plot(X_test['Средний чек'], mr.predict(X_test), 'bo')
plt.title('Количество чеков в месяц vs Средний чек (Test set)')
plt.xlabel('Средний чек')
plt.ylabel('Количество чеков в месяц')
plt.show()

# %%
# Checking p-values
import statsmodels.api as sm
X1 = sm.add_constant(X_train)
mr1 = sm.OLS(y_train, X1).fit()
#mr1.pvalues
mr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     Количество чеков в месяц   R-squared:                       0.555
# Model:                                  OLS   Adj. R-squared:                  0.454
# Method:                       Least Squares   F-statistic:                     5.481
# Date:                      Wed, 12 Jan 2022   Prob (F-statistic):           3.04e-05
# Time:                              14:08:27   Log-Likelihood:                -513.55
# No. Observations:                        55   AIC:                             1049.
# Df Residuals:                            44   BIC:                             1071.
# Df Model:                                10
# Covariance Type:                  nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Recursive feature elimination

# %%
# Feature ranking with recursive feature elimination
from sklearn.feature_selection import RFE
n_features = X.shape[1]
estimator = LinearRegression()
selector = RFE(estimator, n_features_to_select = 3)
selector = selector.fit(X, y)

# Selected Features
selected_columns=[]
for i in range(n_features):
    if selector.support_[i] == True:
        selected_columns.append(i)
        
f_lm = []
for column in selected_columns:
    f_lm.append(X.columns[column])

# %%
# Fitting Optimized Multiple Regression
mr_rfe = LinearRegression().fit(X_train[f_lm], y_train)

# Getting parameters
mr_rfe.coef_, mr_rfe.intercept_
# Out:
# (array([-4071.65956103, -1425.33303971,  2748.08025154]), 8497.632851295046)

# %%
# Predicting the Test set results
y_pred = mr_rfe.predict(X_test[f_lm])

# Coefficient of determination R^2
mr_rfe.score(X_train[f_lm], y_train).round(3)
# Out:
# 0.26

# %%
# Mean squared error
mean_squared_error(y_train, mr_rfe.predict(X_train[f_lm]), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (3542.06, 3060.25)

# %%
# Visualising the Test set results
plt.scatter(X_test['Средний чек'], y_test, color = 'red')
plt.plot(X_test['Средний чек'], mr_rfe.predict(X_test[f_lm]), 'bo')
plt.title('Количество чеков в месяц vs Средний чек (Test set)')
plt.xlabel('Средний чек')
plt.ylabel('Количество чеков в месяц')
plt.show()

# %% [markdown]
# ### Backward Elimination

# %%
# Backward Elimination with p-values
def backwardElimination(x, y, sl):
    x = sm.add_constant(x)
    numVars = x.shape[1]
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j] == maxVar):
                    x = x.drop(x.columns[j], axis=1)
    regressor_OLS.summary()
    return x

SL = 0.0001
X_Modeled = backwardElimination(X_train, y_train, SL)

# %%
# Fitting Optimized Multiple Regression
mr_be = LinearRegression().fit(X_Modeled, y_train)

# Coefficient of determination R^2
mr_be.score(X_Modeled, y_train).round(3)
# Out:
# 0.312

# %% [markdown]
# ### Polynomial Regression

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
X_train_p = PolynomialFeatures().fit_transform(X_train)
X_test_p = PolynomialFeatures().fit_transform(X_test)

pr = LinearRegression().fit(X_train_p, y_train)

# Getting parameters
pr.coef_, pr.intercept_
# Out:
# (array([-2.06322173e-01, -2.94876157e+03,  8.86081746e+04,  2.12664800e+05,
#          5.60341185e+03,  7.87016728e+01,  2.23526672e+00, -3.04630997e+03,
#          1.85611785e+03, -1.96287611e+03,  2.09740476e+04, -6.82713129e+00,
#          1.03194723e+03,  4.68945688e+02,  9.27451221e+00,  7.00692089e-02,
#          1.93142475e-02,  4.05863817e+02, -1.50482598e+03,  1.58918743e+03,
#          1.48800475e+02,  8.86081638e+04,  1.40738457e+03, -1.51845376e+03,
#         -6.10578977e+00,  2.53839871e+00,  1.01787907e+04, -1.07161126e+04,
#         -1.84549868e+04, -2.12081203e+04, -7.15616154e+03, -8.35478411e+02,
#         -8.16683983e+00,  1.19615619e+00,  1.60218752e+04, -9.77672053e+03,
#          3.75895225e+02, -1.87340500e+04,  3.07687886e-01, -1.93828145e-01,
#         -8.56326625e-02, -7.96366879e+02,  2.33032676e+03, -9.97731387e+02,
#          2.81987378e+02, -1.27249620e-03, -1.61033808e-04, -4.52434399e-01,
# ...

# %%
# Predicting the Test set results
y_pred = pr.predict(X_test_p)

# Coefficient of determination R^2
pr.score(X_train_p, y_train).round(3)
# Out:
# 0.94

# %%
# Mean squared error
mean_squared_error(y_train, pr.predict(X_train_p), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (1009.93, 23469.01)

# %%
# Visualising the Test set results
plt.scatter(X_test['Средний чек'], y_test, color = 'red')
plt.plot(X_test['Средний чек'], pr.predict(X_test_p), 'bo')
plt.title('Количество чеков в месяц vs Средний чек (Test set)')
plt.xlabel('Средний чек')
plt.ylabel('Количество чеков в месяц')
plt.show()

# %% [markdown]
# У полиномиальной регрессии слишком большая разница среднеквадратических ошибок (1009.93, 23469.01)
#
# Multiple Linear Regression показала лучший результат
#
# Эта модель показала наилучший коефициент детерминации (0.555).
# Оценивая среднеквадратические ошибки (2747.19, 3821.97), можно сказать, что модель не переобучена.
